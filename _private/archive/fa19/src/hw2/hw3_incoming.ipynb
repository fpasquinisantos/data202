# %% [markdown]
# * Tech
#   * Access and convert data
#
# * Comm
#   * Compare multiple visual representations of the same data.
#
# * Ethics
#   * Trace the provenance of a dataset
#   * Identify and prioritize reproducibility isuses.
#
# Knowledge:
#
# * Data types
# * Provenance and reproducibility (a brief taste)

# %%
  * Access and convert data

# %% [markdown]
# What does the following plot

# %%
sns.barplot(x='mnth', y='registered', hue="workingday", data=daily_counts)
