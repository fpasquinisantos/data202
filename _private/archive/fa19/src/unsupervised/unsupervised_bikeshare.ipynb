# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import requests

# %% [markdown]
# # Folium library

# %% [markdown]
# We'll be using Folium, a mapping library. You may need to run the following cell (after un-commenting it) and restart the kernel.

# %%
#!pip install --user folium

# %%
import folium

# %% [markdown]
# # Capital Bikeshare Rides Data
#
# Download the [2011 trip data](https://s3.amazonaws.com/capitalbikeshare-data/2011-capitalbikeshare-tripdata.zip) from [Capital Bikeshare](https://www.capitalbikeshare.com/system-data). Don't need to unzip the ZIP file; Pandas will handle it:

# %%
#rides = pd.read_csv("../hw6/2011-capitalbikeshare-tripdata.zip")
#ROOT = "/home/cs/data202/CaptialBikeShare/"
ROOT = '../data/capital_bikeshare/'
rides = pd.concat([
    pd.read_csv(
        f"{ROOT}/2019{month:02d}-capitalbikeshare-tripdata.zip",
    usecols=["Duration", "Start date", "End date", "Start station number", "End station number", "Member type"])
    for month in range(1, 11)
])
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3013027 entries, 0 to 337551
# Data columns (total 6 columns):
# Duration                int64
# Start date              object
# End date                object
# Start station number    int64
# End station number      int64
# Member type             object
# dtypes: int64(3), object(3)
# memory usage: 160.9+ MB

# %%
print('{:,d}'.format(len(rides)))
rides.head()
# Out:
# 3,013,027
#    Duration           Start date             End date  Start station number  \
# 0       230  2019-01-01 00:04:48  2019-01-01 00:08:39                 31203
# 1      1549  2019-01-01 00:06:37  2019-01-01 00:32:27                 31321
# 2       177  2019-01-01 00:08:46  2019-01-01 00:11:44                 31104
# 3       228  2019-01-01 00:08:47  2019-01-01 00:12:35                 31281
# 4      1300  2019-01-01 00:12:29  2019-01-01 00:34:10                 31014
#
#    End station number Member type
# 0               31200      Member
# 1               31114      Casual
# 2               31323      Casual
# 3               31280      Member
# 4               31923      Member

# %%
rides['start_datetime'] = pd.to_datetime(rides['Start date'])
rides['start_hour'] = rides['start_datetime'].dt.hour

# %% [markdown]
# # Station Data
# Let's get the [info about each station](https://gbfs.capitalbikeshare.com/gbfs/en/station_information.json).
#
# Main things to notice in this section:
#
# * **JSON is a useful format for structured data**.
# * The `requests` library is a relatively easy way to automatically fetch data from the Web
# * Pandas can make a DataFrame from a list of `dict`s.

# %%
station_info_response = requests.get("https://gbfs.capitalbikeshare.com/gbfs/en/station_information.json")
station_info_response_json = station_info_response.json()

# %%
stations = pd.DataFrame(station_info_response_json['data']['stations'])

# %%
print(len(stations), 'stations')
stations.head()
# Out:
# 574 stations
#    capacity  eightd_has_key_dispenser  \
# 0        19                     False
# 1        23                     False
# 2        35                     False
# 3        14                     False
# 4        11                     False
#
#                              eightd_station_services  \
# 0  [{'id': '5029b3a1-a049-46f9-a13c-c7ffef2bb88c'...
# 1  [{'id': '6944e559-dc16-4a55-9125-e2c3256e294e'...
# 2  [{'id': '2a0089f1-ce95-4633-9471-61b0f70b7c08'...
# 3                                                NaN
# 4                                                NaN
#
#    electric_bike_surcharge_waiver                           external_id  \
# 0                           False  08249be7-1f3f-11e7-bf6b-3863bb334450
# 1                           False  0824aa39-1f3f-11e7-bf6b-3863bb334450
# 2                           False  0824c80d-1f3f-11e7-bf6b-3863bb334450
# 3                           False  082469cc-1f3f-11e7-bf6b-3863bb334450
# 4                           False  08246b69-1f3f-11e7-bf6b-3863bb334450
#
#    has_kiosk        lat        lon                              name  \
# 0       True  38.902221 -77.059219    Georgetown Harbor / 30th St NW
# 1       True  38.900283 -77.029822         13th St & New York Ave NW
# 2       True  38.902061 -77.038322  17th & K St NW / Farragut Square
# 3       True  38.858971 -77.053230               Eads St & 15th St S
# 4       True  38.857250 -77.053320               18th St & S Eads St
#
#    region_id     rental_methods  \
# 0         42  [KEY, CREDITCARD]
# 1         42  [KEY, CREDITCARD]
# 2         42  [KEY, CREDITCARD]
# 3         41  [KEY, CREDITCARD]
# 4         41  [KEY, CREDITCARD]
#
#                                           rental_url short_name station_id
# 0  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...      31215         72
# 1  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...      31227         91
# 2  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...      31233        106
# 3  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...      31000          1
# 4  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...      31001          2

# %%
stations['short_name'] = pd.to_numeric(stations['short_name'])

# %%
stations.query('short_name == 31203')
# Out:
#     capacity  eightd_has_key_dispenser eightd_station_services  \
# 26        23                     False                     NaN
#
#     electric_bike_surcharge_waiver                           external_id  \
# 26                           False  08247a21-1f3f-11e7-bf6b-3863bb334450
#
#     has_kiosk      lat      lon                        name  region_id  \
# 26       True  38.9086 -77.0323  14th & Rhode Island Ave NW         42
#
#        rental_methods                                         rental_url  \
# 26  [KEY, CREDITCARD]  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...
#
#     short_name station_id
# 26       31203         25

# %% [markdown]
# # Adding traffic data
# By "traffic" I mean ridership by station.

# %%
rides['am_pm'] = ["AM" if hour < 12 else "PM" for hour in rides['start_hour']]

# %%
traffic_data = pd.merge(
    rides.groupby(['Start station number', 'am_pm']).size().unstack(),
    rides.groupby(['End station number', 'am_pm']).size().unstack(),
    suffixes=["_departures", "_arrivals"],
    left_index=True, right_index=True
)

stations_with_traffic = pd.merge(
    stations,
    traffic_data,
    left_on="short_name", right_index=True,
    how='inner'
)
stations_with_traffic.head()
# Out:
#    capacity  eightd_has_key_dispenser  \
# 0        19                     False
# 1        23                     False
# 2        35                     False
# 3        14                     False
# 4        11                     False
#
#                              eightd_station_services  \
# 0  [{'id': '5029b3a1-a049-46f9-a13c-c7ffef2bb88c'...
# 1  [{'id': '6944e559-dc16-4a55-9125-e2c3256e294e'...
# 2  [{'id': '2a0089f1-ce95-4633-9471-61b0f70b7c08'...
# 3                                                NaN
# 4                                                NaN
#
#    electric_bike_surcharge_waiver                           external_id  \
# 0                           False  08249be7-1f3f-11e7-bf6b-3863bb334450
# 1                           False  0824aa39-1f3f-11e7-bf6b-3863bb334450
# 2                           False  0824c80d-1f3f-11e7-bf6b-3863bb334450
# 3                           False  082469cc-1f3f-11e7-bf6b-3863bb334450
# 4                           False  08246b69-1f3f-11e7-bf6b-3863bb334450
#
#    has_kiosk        lat        lon                              name  \
# 0       True  38.902221 -77.059219    Georgetown Harbor / 30th St NW
# 1       True  38.900283 -77.029822         13th St & New York Ave NW
# 2       True  38.902061 -77.038322  17th & K St NW / Farragut Square
# 3       True  38.858971 -77.053230               Eads St & 15th St S
# 4       True  38.857250 -77.053320               18th St & S Eads St
#
#    region_id     rental_methods  \
# 0         42  [KEY, CREDITCARD]
# 1         42  [KEY, CREDITCARD]
# 2         42  [KEY, CREDITCARD]
# 3         41  [KEY, CREDITCARD]
# 4         41  [KEY, CREDITCARD]
#
#                                           rental_url  short_name station_id  \
# 0  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...       31215         72
# 1  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...       31227         91
# 2  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...       31233        106
# 3  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...       31000          1
# 4  http://app.capitalbikeshare.com/vIiR/zVsfTIsOT...       31001          2
#
#    AM_departures  PM_departures  AM_arrivals  PM_arrivals
# 0         1906.0         8887.0       8186.0       9849.0
# 1         2054.0         7481.0      11983.0       5647.0
# 2         3006.0         9626.0      13523.0       7834.0
# 3          530.0          908.0        223.0       1045.0
# 4          525.0         1287.0        295.0       1351.0

# %% [markdown]
# # Viewing data on a map
#
# Main things to notice:
# * **latitude and longitude** are the main two things you need for displaying map data.
# * Geographic data usually needs a **base map** to be useful. Different base maps are useful in different circumstances
# * Map data, especially base maps, may be proprietary (needs license keys).

# %%
# Try un-commenting the different "tiles" lines, one at a time.
folium.Map(
    location=[42.961111, -85.655556],
    #tiles='Stamen Toner',
    #tiles="CartoDB positron",
    #tiles="CartoDB dark_matter",
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now here's how we can add our stations:

# %%
m = folium.Map(
    location=[39, -77.],
    tiles='Stamen Toner',
    zoom_start=10
)

for station in stations_with_traffic.itertuples():
    folium.CircleMarker(
        location=[station.lat, station.lon],
        tooltip=station.name,
        fill=True,
        radius=2
    ).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Coloring data by region

# %% [markdown]
# We need to manually specify what colors to use.
#
# We'll pick a color scheme from [ColorBrewer](http://colorbrewer2.org/#type=qualitative&scheme=Paired&n=6).
#
# Notice that there are 3 different types of color schemes:
# * diverging
# * sequential
# * qualitative
#
# Note also that we often express colors in hexadecimal (red-green-blue, two hex digits each).

# %%
colors = sns.color_palette("Paired")
sns.palplot(colors)
color_codes = colors.as_hex()
color_codes
# Out:
# ['#a6cee3',
#  '#1f78b4',
#  '#b2df8a',
#  '#33a02c',
#  '#fb9a99',
#  '#e31a1c',
#  '#fdbf6f',
#  '#ff7f00',
#  '#cab2d6',
#  '#6a3d9a',
#  '#ffff99',
#  '#b15928']

# %% [markdown]
# The `stations` data includes a `region_id`, which looks like it might identify which geographic region a station is in.

# %%
stations.region_id.value_counts()
# Out:
# 42     302
# 41      92
# 44      46
# 43      36
# 104     34
# 40      31
# 133     23
# 152     10
# Name: region_id, dtype: int64

# %%
region_to_color = dict(zip(stations_with_traffic.region_id.unique(), color_codes))
region_to_color
# Out:
# {42: '#a6cee3',
#  41: '#1f78b4',
#  40: '#b2df8a',
#  44: '#33a02c',
#  43: '#fb9a99',
#  104: '#e31a1c',
#  133: '#fdbf6f',
#  152: '#ff7f00'}

# %%
stations_with_traffic['marker_color'] = stations.region_id.map(region_to_color)

# %%
m = folium.Map(
    location=[39, -77.],
    tiles='Stamen Toner',
    zoom_start=10
)

for station in stations_with_traffic.itertuples():
    folium.CircleMarker(
        location=[station.lat, station.lon],
        tooltip=station.name,
        color=station.marker_color,
        radius=2,
        fill=True
    ).add_to(m)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Data organized by regions are useful for analysis

# %%
(
    stations_with_traffic
    .groupby('region_id')
    [['AM_departures', 'AM_arrivals', 'PM_departures', 'PM_arrivals']]
    .mean()
    .T
    .style.bar(vmax=6000)
)
# Out:
# <style  type="text/css" >
#     #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 1.4%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 1.2%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.7%, transparent 1.7%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col6 {
#             width:  10em;
#              height:  80%;
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col7 {
#             width:  10em;
#              height:  80%;
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.6%, transparent 10.6%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.7%, transparent 16.7%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.3%, transparent 96.3%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.8%, transparent 5.8%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.8%, transparent 1.8%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.3%, transparent 14.3%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.9%, transparent 95.9%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.6%, transparent 5.6%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
#         }    #T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.0%, transparent 3.0%);
#         }</style><table id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9" ><thead>    <tr>        <th class="index_name level0" >region_id</th>        <th class="col_heading level0 col0" >40</th>        <th class="col_heading level0 col1" >41</th>        <th class="col_heading level0 col2" >42</th>        <th class="col_heading level0 col3" >43</th>        <th class="col_heading level0 col4" >44</th>        <th class="col_heading level0 col5" >104</th>        <th class="col_heading level0 col6" >133</th>        <th class="col_heading level0 col7" >152</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9level0_row0" class="row_heading level0 row0" >AM_departures</th>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col0" class="data row0 col0" >695.774</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col1" class="data row0 col1" >880.011</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col2" class="data row0 col2" >2938.11</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col3" class="data row0 col3" >138.722</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col4" class="data row0 col4" >312.261</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col5" class="data row0 col5" >150.235</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col6" class="data row0 col6" >70.2609</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row0_col7" class="data row0 col7" >136.3</td>
#             </tr>
#             <tr>
#                         <th id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9level0_row1" class="row_heading level0 row1" >AM_arrivals</th>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col0" class="data row1 col0" >619.645</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col1" class="data row1 col1" >779.598</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col2" class="data row1 col2" >2989.85</td>
#                         <td id="T_7aa7b3d2_0b9c_11ea_8702_8569bc2a1fc9row1_col3" class="data row1 col3" >1

# %% [markdown]
# # Clustering
#
# What if the data didn't come with `region_id`? We could use *clustering* to discover spatially similar regions.
#
# There are many different kinds of clustering algorithms, but *k-means* is a very common one because it's simple and often works reasonably.

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# One downside of k-means is we need to tell it how many clusters to look for.

# %%
km = KMeans(n_clusters=8)

# %%
# We'll use the latitude and longitude as features to cluster by.
# np.c_[] constructs a 2D array from columns.
X = np.c_[
    1.0 * stations_with_traffic['lat'],
    1.0 * stations_with_traffic['lon']
]
X.shape
# Out:
# (572, 2)

# %%
# clustering objects have a similar interface to classifiers:
km.fit(X)

stations_with_traffic['kmeans_cluster'] = km.predict(X)

stations_with_traffic['kmeans_cluster'].value_counts()
# Out:
# 0    174
# 3    108
# 5     76
# 4     72
# 7     61
# 1     36
# 2     29
# 6     16
# Name: kmeans_cluster, dtype: int64

# %%
cluster_to_color = dict(enumerate(color_codes.copy()))
stations_with_traffic['marker_color'] = stations_with_traffic['kmeans_cluster'].map(cluster_to_color)

# %%
m = folium.Map(
    location=[39, -77.],
    tiles='Stamen Toner',
    zoom_start=10
)

for station in stations_with_traffic.itertuples():
    folium.CircleMarker(
        location=[station.lat, station.lon],
        tooltip=station.name,
        color=station.marker_color,
        radius=2
    ).add_to(m)

for cluster, cluster_center in enumerate(km.cluster_centers_):
    folium.CircleMarker(
        location=cluster_center,
        radius=10,
        color=mpl.colors.rgb2hex(sns.desaturate(cluster_to_color[cluster], .5)),
        fill=True,
    ).add_to(m)
    
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
(
    stations_with_traffic
    .groupby('kmeans_cluster')
    [['AM_departures', 'AM_arrivals', 'PM_departures', 'PM_arrivals']]
    .mean()
    .T
    .style.bar(width=90)
)
# Out:
# <style  type="text/css" >
#     #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 1.2%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.8%, transparent 22.8%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.7%, transparent 29.7%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.3%, transparent 13.3%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.0%, transparent 9.0%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col4 {
#             width:  10em;
#              height:  80%;
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col6 {
#             width:  10em;
#              height:  80%;
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col7 {
#             width:  10em;
#              height:  80%;
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.1%, transparent 65.1%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 81.4%, transparent 81.4%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 83.5%, transparent 83.5%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.8%, transparent 88.8%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 85.1%, transparent 85.1%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.5%, transparent 78.5%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 83.1%, transparent 83.1%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.2%, transparent 88.2%);
#         }    #T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }</style><table id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9" ><thead>    <tr>        <th class="index_name level0" >kmeans_cluster</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9level0_row0" class="row_heading level0 row0" >AM_departures</th>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col0" class="data row0 col0" >3737.75</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col1" class="data row0 col1" >138.722</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col2" class="data row0 col2" >153.897</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col3" class="data row0 col3" >1867.99</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col4" class="data row0 col4" >480.361</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col5" class="data row0 col5" >889.658</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col6" class="data row0 col6" >156.812</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row0_col7" class="data row0 col7" >722.311</td>
#             </tr>
#             <tr>
#                         <th id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9level0_row1" class="row_heading level0 row1" >AM_arrivals</th>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col0" class="data row1 col0" >4176.08</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col1" class="data row1 col1" >137.5</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col2" class="data row1 col2" >156.966</td>
#                         <td id="T_7b134fc0_0b9c_11ea_8702_8569bc2a1fc9row1_col3" class
