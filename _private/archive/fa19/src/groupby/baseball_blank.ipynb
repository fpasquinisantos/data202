# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# //anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# //anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# //anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# //anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
players = pd.read_csv("https://raw.githubusercontent.com/chadwickbureau/baseballdatabank/master/core/People.csv")
players.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay  ... nameLast       nameGiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile        NaN         NaN       NaN  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalGame   retroID    bbrefID
# ...

# %%
salaries = pd.read_csv("https://raw.githubusercontent.com/chadwickbureau/baseballdatabank/master/core/Salaries.csv")
salaries.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
teams = pd.read_csv("https://github.com/chadwickbureau/baseballdatabank/raw/master/core/Teams.csv")
teams.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8  0.803
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14  0.840
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %% [markdown]
# # Which teams won the World Series each year?

# %% [markdown]
# `query` for winners

# %% [markdown]
# # Payroll by team and year

# %%
salaries.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
payrolls = ...
print(len(payrolls))
# Out:
# 918
#    yearID teamID    salary
# 0    1985    ATL  14807000
# 1    1985    BAL  11560712
# 2    1985    BOS  10897560
# 3    1985    CAL  14427894
# 4    1985    CHA   9846178

# %%
payroll_teams = pd.merge(teams, payrolls, on=['yearID', 'teamID'], how='inner')
print(len(payroll_teams))
payroll_teams.head()
# Out:
# 918
#    yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...     FP  \
# 0    1985   NL    ATL      ATL     W     5  162   81.0  66  96  ...  0.976
# 1    1985   AL    BAL      BAL     E     4  161   81.0  83  78  ...  0.979
# 2    1985   AL    BOS      BOS     E     5  163   81.0  81  81  ...  0.977
# 3    1985   AL    CAL      ANA     W     2  162   79.0  90  72  ...  0.982
# 4    1985   AL    CHA      CHW     W     3  163   81.0  85  77  ...  0.982
#
#                 name                           park attendance  BPF  PPF  \
# 0     Atlanta Braves  Atlanta-Fulton County Stadium  1350137.0  105  106
# 1  Baltimore Orioles               Memorial Stadium  2132387.0   97   97
# 2     Boston Red Sox                 Fenway Park II  1786633.0  104  104
# 3  California Angels                Anaheim Stadium  2567427.0  100  100
# 4  Chicago White Sox                  Comiskey Park  1669888.0  104  104
#
#    teamIDBR  teamIDlahman45  teamIDretro    salary
# ...

# %%
sns.scatterplot(x="yearID", y="salary", hue="WSWin", data=payroll_teams)
