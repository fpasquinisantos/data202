# %% [markdown]
# ## Question 4.2
# Something is weird about this situation. The training MSEs are so much better than our testing MSEs.

# %%
train_y.mean()
# Out:
# 143.79444765760556

# %%
test_y.mean()
# Out:
# 234.6663613464621

# %% [markdown]
# # Two predictors!

# %%
train_x = train[['temp', 'hour']].values
train_y = train['riders'].values

# %%
test_x = test[['temp', 'hour']].values
test_y = test['riders'].values

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(train_x, train_y)
# Why does this fail?
y_predicted = knn.predict(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-328d624e2058> in <module>
#       2 knn.fit(train_x, train_y)
#       3 # Why does this fail?
# ----> 4 y_predicted = knn.predict(x)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/neighbors/regression.py in predict(self, X)
#     155         X = check_array(X, accept_sparse='csr')
#     156
# --> 157         neigh_dist, neigh_ind = self.kneighbors(X)
#     158
#     159         weights = _get_weights(neigh_dist, self.weights)
#
# //anaconda3/lib/python3.7/site-packages/sklearn/neighbors/base.py in kneighbors(self, X, n_neighbors, return_distance)
#     452                 delayed_query(
#     453                     self._tree, X[s], n_neighbors, return_distance)
# --> 454                 for s in gen_even_slices(X.shape[0], n_jobs)
#     455             )
#     456         else:
#
# ...

# %%
x = np.zeros((100, ))
plt.scatter(train_x, train_y, s=.3)
plt.plot(x, y_predicted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-06b12ceaee8f> in <module>
# ----> 1 plt.scatter(train_x, train_y, s=.3)
#       2 plt.plot(x, y_predicted)
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2839         verts=verts, edgecolors=edgecolors,
#    2840         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2841         None else {}), **kwargs)
#    2842     sci(__ret)
#    2843     return __ret
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
# ...

# %%
metrics.mean_squared_error(y_true=train_y, y_pred=knn.predict(train_x))
# Out:
# 16239.13789705032

# %%
metrics.mean_squared_error(y_true=test_y, y_pred=knn.predict(test_x))
# Out:
# 50482.16887565835

# %%
linreg = LinearRegression()
linreg.fit(train_x, train_y)
plt.scatter(train_x, train_y, s=.3)
plt.plot(x, linreg.predict(x))

# %%
metrics.mean_squared_error(y_true=train_y, y_pred=linreg.predict(train_x))
# Out:
# 14255.20339011402

# %%
metrics.mean_squared_error(y_true=test_y, y_pred=linreg.predict(test_x))
# Out:
# 44780.33106938273
