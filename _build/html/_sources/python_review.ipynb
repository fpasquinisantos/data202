# %% [markdown]
# # Python Review + Numpy
#
# ```{admonition} Learning Objectives Covered
# :class: dropdown
# |||
# |-------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | WRA02 | I can create and work with **arrays using NumPy**.                                                                                                                                       |
# ```
#
# Coming soon.
