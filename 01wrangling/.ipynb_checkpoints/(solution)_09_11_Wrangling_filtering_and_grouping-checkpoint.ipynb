# %% [markdown]
# > Heavenly Father,
# >
# > We come before You, seeking wisdom and discernment in our work with data. Grant us the understanding to represent information truthfully and fairly, knowing that each data point reflects the reality of lives, stories, and experiences.
# >
# > Guide our minds as we organize, analyze, and interpret data, so that our actions may honor Your principles of justice and truth. Help us to avoid bias, to present findings transparently, and to use data in ways that uplift and inform rather than mislead or harm.
# >
# > May our efforts in data wrangling and analysis be instruments of clarity, bringing light to hidden truths, and contributing positively to the world around us. Teach us to be humble in our knowledge, always seeking to learn and grow, and to use our skills with integrity and care.
# >
# > In Your wisdom, we trust. Amen.

# %% [markdown]
# # Retrieval
#
# Our dataset for this class is about alcohol consumption by secondary school students. The data were obtained in a survey of students math and portuguese language courses, in two schools, and can be found at [Kaggle](https://www.kaggle.com/datasets/uciml/student-alcohol-consumption/data).
#
# Each row represents a student, and the columns are:
#
# - school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# - sex - student's sex (binary: 'F' - female or 'M' - male)
# - age - student's age (numeric: from 15 to 22)
# - address - student's home address type (binary: 'U' - urban or 'R' - rural)
# - famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# - Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# - Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# - Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# - Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# - Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# - reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# - guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# - traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# - studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# - failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# - schoolsup - extra educational support (binary: yes or no)
# - famsup - family educational support (binary: yes or no)
# - paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# - activities - extra-curricular activities (binary: yes or no)
# - nursery - attended nursery school (binary: yes or no)
# - higher - wants to take higher education (binary: yes or no)
# - internet - Internet access at home (binary: yes or no)
# - romantic - with a romantic relationship (binary: yes or no)
# - famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# - freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# - goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# - Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - health - current health status (numeric: from 1 - very bad to 5 - very good)
# - absences - number of school absences (numeric: from 0 to 93)
# - G1 - first period grade (numeric: from 0 to 20)
# - G2 - second period grade (numeric: from 0 to 20)
# - G3 - final grade (numeric: from 0 to 20, output target)
#
# Let's retrieve what we learned last time!

# %% [markdown]
# - Load the CSV file for the math course (`student-mat.csv`) into a Pandas DataFrame named `students`.

# %%
import pandas as pd
students = pd.read_csv('student-mat.csv')
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# - Select and display the data for the student at index 5.

# %%
students.iloc[5]
# Out:
# school                GP
# sex                    M
# age                   16
# address                U
# famsize              LE3
# Pstatus                T
# Medu                   4
# Fedu                   3
# Mjob            services
# Fjob               other
# reason        reputation
# guardian          mother
# traveltime             1
# studytime              2
# failures               0
# schoolsup             no
# famsup               yes
# paid                 yes
# activities           yes
# nursery              yes
# higher               yes
# internet             yes
# romantic              no
# famrel                 5
# freetime               4
# goout                  2
# Dalc                   1
# Walc                   2
# health                 5
# absences              10
# G1                    15
# G2                    15
# G3                    15
# Name: 5, dtype: object

# %% [markdown]
# - Select and display the G3 column (final grade) for all students.

# %%
students['G3']
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %% [markdown]
# - Create a new column named `total_grade` which is the sum of G1 and G2 and display the first few rows.

# %%
students['total_grade'] = students['G1'] + students['G2']
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 total_grade
# 0        3     4     1     1       3        6   5   6   6          11
# 1        3     3     1     1       3        4   5   5   6          10
# 2        3     2     2     3       3       10   7   8  10          15
# 3        2     2     1     1       5        2  15  14  15          29
# 4        3     2     1     2       5        4   6  10  10          16
#
# [5 rows x 34 columns]

# %% [markdown]
# - Sort the DataFrame by age in ascending order and display the first few rows.

# %%
students.sort_values(by='age').head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 130     GP   F   15       R     GT3       T     3     4  services  teacher
# 102     GP   M   15       U     GT3       T     4     4  services    other
# 103     GP   F   15       U     GT3       T     3     2  services    other
# 104     GP   M   15       U     GT3       A     3     4  services    other
# 105     GP   F   15       U     GT3       A     3     3     other   health
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 total_grade
# 130  ...        2     2     2     2       5        0  12   0   0          12
# 102  ...        3     3     1     1       5        4  10  13  14          23
# 103  ...        3     5     1     1       2       26   7   6   6          13
# 104  ...        4     4     1     1       1        0  16  18  18          34
# 105  ...        3     3     1     1       4       10  10  11  11          21
#
# [5 rows x 34 columns]

# %% [markdown]
# - Calculate and display the mean of the G3 column (final grade).

# %%
students['G3'].mean()
# Out:
# 10.415189873417722

# %% [markdown]
# # Filtering dataframes

# %% [markdown]
# ## 1. Filter by a Single Condition

# %%
# Filter rows where 'age' is greater than 18
students_age_filtered = students[students['age'] > 18]
students_age_filtered.head()

# %% [markdown]
# - **(📝Your Turn!)** In the same way, let's now filter rows where 'G3' is greater than 15.

# %%
students_big_g3 = students[students['G3'] > 15]
students_big_g3.head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 8      GP   M   15       U     LE3       A     3     2  services     other
# 14     GP   M   15       U     GT3       A     2     2     other     other
# 22     GP   M   16       U     LE3       T     4     2   teacher     other
# 31     GP   M   15       U     GT3       T     4     4  services  services
# 32     GP   M   15       R     GT3       T     4     3   teacher   at_home
#
#     ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 total_grade
# 8   ...        2     2     1     1       1        0  16  18  19          34
# 14  ...        5     2     1     1       3        0  14  16  16          30
# 22  ...        5     1     1     3       5        2  15  15  16          30
# 31  ...        3     1     1     1       5        0  17  16  17          33
# 32  ...        5     2     1     1       5        0  17  16  16          33
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 2. Filter by Multiple Conditions

# %%
# Filter rows where 'age' > 18 and 'G3' > 15
students_multiple_conditions = students[(students['age'] > 18) & (students['G3'] > 15)]
students_multiple_conditions.head()

# %% [markdown]
# - **(📝Your Turn!)** In the same way, let's now filter rows where 'age' <= 18 OR 'studytime' = 4.

# %%
students_multiple_conditions = students[(students['age'] <= 18) | (students['studytime'] == 4)]
students_multiple_conditions.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 total_grade
# 0        3     4     1     1       3        6   5   6   6          11
# 1        3     3     1     1       3        4   5   5   6          10
# 2        3     2     2     3       3       10   7   8  10          15
# 3        2     2     1     1       5        2  15  14  15          29
# 4        3     2     1     2       5        4   6  10  10          16
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 3. Filter by Categorical Column

# %%
# Filter rows where 'school' is 'GP'
students_school_gp = students[students['school'] == 'GP']
students_school_gp.head()

# %% [markdown]
# - **(📝Your Turn!)** In the same way, let's now filter rows where 'activities' (extra-curricular activities) is 'yes'.

# %%
students_activities_yes = students[students['activities'] == 'yes']
students_activities_yes.head()
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 5      GP   M   16       U     LE3       T     4     3  services     other
# 9      GP   M   15       U     GT3       T     3     4     other     other
# 11     GP   F   15       U     GT3       T     2     1  services     other
# 12     GP   M   15       U     LE3       T     4     4    health  services
#
#     ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 total_grade
# 3   ...        2     2     1     1       5        2  15  14  15          29
# 5   ...        4     2     1     2       5       10  15  15  15          30
# 9   ...        5     1     1     1       5        0  14  15  15          29
# 11  ...        2     2     1     1       4        4  10  12  12          22
# 12  ...        3     3     1     3       5        2  14  14  14          28
#
# [5 rows x 34 columns]

# %% [markdown]
# ## 4. Filter with the `query()` method

# %%
# Filter using query method
students_query = students.query("famsize == 'GT3' and famsup == 'no'")
students_query.head()

# %% [markdown]
# - **(📝Your Turn!)** In the same way, let's now filter rows where `failures < 2` and `higher == yes`.

# %%
students_query = students.query("failures < 2 and higher == 'yes'")
students_query.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
#
#    ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 total_grade
# 0  ...        3     4     1     1       3        6   5   6   6          11
# 1  ...        3     3     1     1       3        4   5   5   6          10
# 3  ...        2     2     1     1       5        2  15  14  15          29
# 4  ...        3     2     1     2       5        4   6  10  10          16
# 5  ...        4     2     1     2       5       10  15  15  15          30
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Key Points
#
# - **Single Condition**: Use simple boolean conditions for basic filtering.
# - **Multiple Conditions**: Combine conditions using `&` (and) or `|` (or) operators.
# - **`query()` Method**: Use `query()` for a more readable and expressive way to filter.

# %% [markdown]
# # Grouping dataframes

# %% [markdown]
# ## Why?
#
# - Quickly compute summary statistics (e.g., mean, sum, count) across different categories or groups.
# - Thus, we can identify trends, patterns, or differences between groups.
#
# - Main idea:
#     1. *Split* the data in groups
#     2. *Apply* some operation (count, sum, mean, etc)
#     3. *Combine* again in a new dataframe.

# %% [markdown]
# ## Grouping by one column
#
# - Let's group by school:

# %%
# Group by 'school' and calculate mean of 'G3'
students_grouped_school = students.groupby('school')
print(students_grouped_school)
print(type(students_grouped_school))
# Out:
# ...
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %% [markdown]
# - **(📝Your Turn!)** What is the following code doing?

# %%
for school, group in students.groupby("school"):
  print(school, "has students with mean age", group)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 344     GP   F   18       U     GT3       T     2     3  at_home     other
# 345     GP   F   18       U     GT3       T     3     2    other  services
# 346     GP   M   18       R     GT3       T     4     3  teacher  services
# 347     GP   M   18       U     GT3       T     4     3  teacher     other
# 348     GP   F   17       U     GT3       T     4     3   health     other
#
# ...

# %% [markdown]
# *describe the purpose of this code...*

# %% [markdown]
# ### Checking group size

# %%
students.groupby("school").size()
# Out:
# school
# GP    349
# MS     46
# dtype: int64

# %%
students.groupby(["school", "sex"]).size()
# Out:
# school  sex
# GP      F      183
#         M      166
# MS      F       25
#         M       21
# dtype: int64

# %% [markdown]
# ### Aggregating into a new dataframe
#
# - What kind of dataframe is being created here?

# %%
students_by_school = (
  students
  .groupby("school", as_index=False)
  .agg(mean_G3=('G3', 'mean'))
)
students_by_school
# Out:
#   school   mean_G3
# 0     GP  1.444126
# 1     MS  1.760870

# %% [markdown]
# **Important:** DON'T FORGET THE ARGUMENT `as_index=False`. This will collapse the groups as standard indexed dataframes. This may not make sense now, but will be crucial when we start plotting and visualizing these dataframes.

# %% [markdown]
# ### A lazy method...

# %%
students_by_school = students.groupby(["school", "sex"], as_index=False)['G3'].mean()
students_by_school = students_by_school.rename(columns={'G3': 'mean_G3'})
students_by_school
# Out:
#   school sex    mean_G3
# 0     GP   F   9.972678
# 1     GP   M  11.060241
# 2     MS   F   9.920000
# 3     MS   M   9.761905

# %% [markdown]
# - Problem: not so easy to understand, and doesn't set the right column name!
# - That's why we will be using the first option!

# %% [markdown]
# - **(📝Your Turn!)** Let's now group by `sex` and have a new dataframe with a column refering to the mean of `age`. Test the more explicit (setting the column name) and the more lazy methods.

# %%
students_by_sex = (
  students
  .groupby("sex", as_index=False)
  .agg(mean_g3=('G3', 'mean'))
)
students_by_sex
# Out:
#   sex    mean_g3
# 0   F   9.966346
# 1   M  10.914439

# %% [markdown]
# ## Grouping by multiple columns

# %%
# Group by 'school' and 'sex' and calculate mean of 'G3'
students_grouped_school_sex = (
    students
    .groupby(['school', 'sex'])
    .agg(mean_G3=('G3', 'mean'))
)
students_grouped_school_sex

# %% [markdown]
# ## Custom Aggregations with `agg()`

# %%
# Custom aggregation functions
custom_agg = students.groupby('school')['G3'].agg(['mean', 'max', lambda x: x.mean() + 1])
print(custom_agg)

# %% [markdown]
# ## Multiple functions with `agg()`

# %%
# Aggregation with multiple functions
multi_agg = students.groupby('school').agg({
  'age': ['mean', 'median'],
  'G3': ['mean', 'std', 'max']
})
print(multi_agg)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# - It is a first look at the dataset, in order to visualize and summarize their main characteristics
# - Used to understand the data structure, detect patterns, identify anomalies, test hypotheses, and check assumptions.

# %% [markdown]
# - In our student dataset, we can ask, for example:
#    - What is the distribution of student ages?
#    - How many students are in each school ('GP' vs. 'MS')?
#    - Do male and female students have different average grades?
#    - How do grades vary based on the mother's education level (Medu)?
#    - Does having internet access at home influence grades?
#    - What is the relationship between family educational support (famsup) and student performance?
#    - Does the family relationship quality (famrel) affect free time or study time?

# %% [markdown]
# - **(📝Your Turn!)** Let's try to create some visualizations for these questions!

# %%
students_address = (
    students
    .groupby(by=['sex','address'], as_index=False)
    .agg(mean_dalc=('Dalc', 'mean'), mean_walc=('Walc', 'mean'))
)
students_address

import plotly.express as px
fig = px.bar(students_address, x='sex', y='mean_dalc', color='address', barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Love, visibility and data

# %% [markdown]
# Hagar, who is Sarah's Egyptian servant, flees into the desert after mistreatment by Sarah. There, she encounters an angel of the Lord who speaks to her and points to a fountain of water. In response to this divine encounter, Hagar declares:
#
# > “So she called the name of the Lord who spoke to her, ‘**You are a God of seeing**,’ for she said, ‘Truly here I have seen him who looks after me.’”
# — Genesis 16:13 (ESV)

# %% [markdown]
# - What if we understand data collection and dissemination as **a form of love and compassion?**
#   - For example, observing alcohol consumption patterns in students.
#
# > "The common gaze is **surveillance for the common good**, inflected with a preferential optic for those who are poor." (see [The Common Gaze, by Eric Stoddard](https://www.amazon.com/Common-Gaze-Surveillance-Good/dp/0334060044), p. 41)
#
# > "Corporations accumulate vast domains of new knowledge from us, but not **for** us." (p. 11)
#
# - What is, instead of watching people, we could "watch for", "watch with", and "watch over" people?
#
#   - Sometimes, even privacy is not an absolute value: there is a lot of crime and injustice that need to be brought to light!

# %% [markdown]
# - Maybe we could call that ***comveillance***: the practice of watching with one another in solidarity.
# - The question could be: **who is allowed to watch whom?**
